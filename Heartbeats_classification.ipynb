# %% [markdown]
# ## Import libraries

# %%
import os
import random
import librosa
import numpy as np
from IPython.display import Audio

# %%
#@title Folder Paths Dataset A
folder_paths_a = [
    './data/train/dataset_a/Atraining_artifact',
    './data/train/dataset_a/Atraining_extrahs',
    './data/train/dataset_a/Atraining_murmur',
    './data/train/dataset_a/Atraining_normal'
]

# %%
#@title Folder Paths Dataset B
folder_paths_b = [
    './data/train/dataset_a/Btraining_extrastole',
    './data/train/dataset_a/Atraining_murmur',
    './data/train/dataset_a/Atraining_normal'
]

# %% [markdown]
# ## About Data

# %% [markdown]
# ### Dataset A

# %%
#@title Normal Heartbeat
folder_path = './data/train/dataset_a/Atraining_normal'
file_names = os.listdir(folder_path)
random_file = random.choice(file_names)

file_path = os.path.join(folder_path, random_file)
audio, _ = librosa.load(file_path, sr=None)

# play audio
Audio(audio, rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@title Extra Heart Sound
folder_path = './data/train/dataset_a/Atraining_extrahs'
file_names = os.listdir(folder_path)
random_file = random.choice(file_names)

file_path = os.path.join(folder_path, random_file)
audio, _ = librosa.load(file_path, sr=None)

# play audio
Audio(audio, rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@title Murmur Heartbeat
folder_path = './data/train/dataset_a/Atraining_murmur'
file_names = os.listdir(folder_path)
random_file = random.choice(file_names)

file_path = os.path.join(folder_path, random_file)
audio, _ = librosa.load(file_path, sr=None)

# play audio
Audio(audio, rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@title Artifact sound
folder_path = './data/train/dataset_a/Atraining_artifact'
file_names = os.listdir(folder_path)
random_file = random.choice(file_names)

file_path = os.path.join(folder_path, random_file)
audio, _ = librosa.load(file_path, sr=None)

# play audio
Audio(audio, rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
